# %% [markdown]
# ### Imports & Declarations

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import datetime as dt
import numpy as np

# %%
states = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA',
          'HI','ID','IL','IN','IA','KS','KY','LA','ME','MD',
          'MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ',
          'NM','NY','NC','ND','OH','OK','OR','PA','RI','SC',
          'SD','TN','TX','UT','VT','VA','WA','WV','WI','WY',
          'PR','MP','VI','GU']
url = 'https://www.cbp.gov/contact/ports/'
ports = {'Port Code':[],'Street Address':[],'City':[],'State':[],'Postal Code':[],'Field':[]}

# %% [markdown]
# # Automated Web Scraping for U.S. Soil CBP Ports

# %%
print('<-- Starting web scrape of ports -->\n')
for state in states:
    # Requesting html for state
    response = requests.get('https://www.cbp.gov/contact/ports/' + state)
    print('-'*20)
    print(f'{state} - {response}')
    print('-'*20)

    # Create soup object for html
    soup = bs(response.text, 'html.parser')

    # Find just the table with the ports
    results = soup.find_all('tr', scope='row')

    # Put ports information into dictionary for later creation of DataFrame
    for result in results:
        try:
            ports['Port Code'].append(result.a.text)
            ports['Street Address'].append(result.div.div.text)
            ports['City'].append(result.span.text)
            ports['State'].append(result.find('span', class_='state').text)
            ports['Postal Code'].append(result.find('span', class_='postal-code').text)
            try:
                ports['Field'].append(result.find_all('a')[1].text)
            except:
                ports['Field'].append(np.NaN)
        except Exception as e:
            print('Error:', e, state)
            
print('\nFinished.')
# Out:
# <-- Starting web scrape of ports -->
#
# --------------------
# AL - <Response [200]>
# --------------------
# --------------------
# AK - <Response [200]>
# --------------------
# --------------------
# AZ - <Response [200]>
# --------------------
# --------------------
# AR - <Response [200]>
# --------------------
# --------------------
# CA - <Response [200]>
# --------------------
# --------------------
# CO - <Response [200]>
# --------------------
# --------------------
# CT - <Response [200]>
# --------------------
# --------------------
# DE - <Response [200]>
# --------------------
# --------------------
# FL - <Response [200]>
# --------------------
# --------------------
# GA - <Response [200]>
# --------------------
# --------------------
# HI - <Response [200]>
# --------------------
# --------------------
# ID - <Response [200]>
# --------------------
# --------------------
# IL - <Response [200]>
# --------------------
# --------------------
# IN - <Response [200]>
# --------------------
# --------------------
# IA - <Response [200]>
# --------------------
# --------------------
# KS - <Response [200]>
# --------------------
# --------------------
# KY - <Response [200]>
# --------------------
# --------------------
# LA - <Response [200]>
# --------------------
# --------------------
# ME - <Response [200]>
# --------------------
# --------------------
# MD - <Response [200]>
# --------------------
# --------------------
# MA - <Response [200]>
# --------------------
# --------------------
# MI - <Response [200]>
# --------------------
# --------------------
# MN - <Response [200]>
# --------------------
# --------------------
# MS - <Response [200]>
# --------------------
# --------------------
# MO - <Response [200]>
# --------------------
# --------------------
# MT - <Response [200]>
# --------------------
# --------------------
# NE - <Response [200]>
# --------------------
# --------------------
# NV - <Response [200]>
# --------------------
# --------------------
# NH - <Response [200]>
# --------------------
# --------------------
# NJ - <Response [200]>
# --------------------
# --------------------
# NM - <Response [200]>
# --------------------
# --------------------
# NY - <Response [200]>
# --------------------
# --------------------
# NC - <Response [200]>
# --------------------
# --------------------
# ND - <Response [200]>
# --------------------
# --------------------
# OH - <Response [200]>
# --------------------
# --------------------
# OK - <Response [200]>
# --------------------
# --------------------
# OR - <Response [200]>
# --------------------
# --------------------
# PA - <Response [200]>
# --------------------
# --------------------
# RI - <Response [200]>
# --------------------
# --------------------
# SC - <Response [200]>
# --------------------
# --------------------
# SD - <Response [200]>
# --------------------
# --------------------
# TN - <Response [200]>
# --------------------
# --------------------
# TX - <Response [200]>
# --------------------
# --------------------
# UT - <Response [200]>
# --------------------
# --------------------
# VT - <Response [200]>
# --------------------
# --------------------
# VA - <Response [200]>
# --------------------
# --------------------
# WA - <Response [200]>
# --------------------
# --------------------
# WV - <Response [200]>
# --------------------
# --------------------
# WI - <Response [200]>
# --------------------
# --------------------
# WY - <Response [200]>
# --------------------
# --------------------
# PR - <Response [200]>
# --------------------
# --------------------
# MP - <Response [200]>
# --------------------
# --------------------
# VI - <Response [200]>
# --------------------
# --------------------
# GU - <Response [200]>
# --------------------
#
# Finished.

# %%
# Create dataframe out of ports dictionary
ports_df = pd.DataFrame(ports)
ports_df
# Out:
#                                              Port Code  \
# 0                           Birmingham, Alabama - 1904
# 1                           Huntsville, Alabama - 1910
# 2          Mobile (Including Theodore), Alabama - 1901
# 3                                 Alcan, Alaska - 3104
# 4                             Anchorage, Alaska - 3126
# 5                          Dalton Cache, Alaska - 3106
# 6                             Fairbanks, Alaska - 3111
# 7                                Juneau, Alaska - 3101
# 8                             Ketchikan, Alaska - 3102
# 9                                Kodiak, Alaska - 3127
# 10                                 Nome, Alaska - 3128
# 11                                Sitka, Alaska - 3115
# 12                              Skagway, Alaska - 3103
# 13                               Valdez, Alaska - 3107
# 14                             Wrangell, Alaska - 3105
# 15                             Douglas, Arizona - 2601
# 16                           Lukeville, Arizona - 2602
# 17                                Naco, Arizona - 2603
# 18                             Nogales, Arizona - 2604
# 19                             Phoenix, Arizona - 2605
# 20        Phoenix-Mesa Gateway Airport, Arizona - 2682
# 21                            San Luis, Arizona - 2608
# 22                              Sasabe, Arizona - 2606
# 23                  Scottsdale Airport, Arizona - 2681
# 24                              Tucson, Arizona - 2609
# 25      Little Rock-North Little Rock, Arkansas - 2003
# 26                     Rogers Airport, Arkansas - 2084
# 27                Andrade - Class A, California - 2502
# 28          Calexico East - Class A, California - 2507
# 29          Calexico West - Class A, California - 2503
# ..                                                 ...
# 304                       Front Royal, Virginia - 1410
# 305          New River Valley Airport, Virginia - 1412
# 306              Norfolk-Newport News, Virginia - 1401
# 307         Port of Washington-Dulles, Virginia - 5401
# 308             Richmond - Petersburg, Virginia - 1404
# 309                          Blaine, Washington - 3004
# 310                        Longview, Washington - 2905
# 311                    Oroville, WA, Washington - 3019
# 312                         Seattle, Washington - 3001
# 313                           Sumas, Washington - 3009
# 314              Tacoma, Washington, Washington - 3002
# 315                   Charleston, West Virginia - 1409
# 316   Appleton International Airport, Wisconsin - 3781
# 317                        Green Bay, Wisconsin - 3703
# 318                        Milwaukee, Wisconsin - 3701
# 319                           Racine, Wisconsin - 3708
# 320             Natrona County Airport, Wyoming - 3332
# 321                      Aguadilla, Puerto Rico - 4901
# 322                        Fajardo, Puerto Rico - 4904
# 323  Luis Munoz Marin International Airport, Puerto...
# 324                       Mayaguez, Puerto Rico - 4907
# 325                          Ponce, Puerto Rico - 4908
# 326       San Juan, PR (Area Port), Puerto Rico - 4909
# 327              Rota, Northern Mariana Islands - 3213
# 328            Saipan, Northern Mariana Islands - 3211
# 329            Tinian, Northern Mariana Islands - 3212
# 330  Charlotte Amalie (Area Port of St. Thomas), Vi...
# 331         Cruz Bay (St. John), Virgin Islands - 5102
# 332                 Saint Croix, Virgin Islands - 5104
# 333                         Hagatna, Guam, Guam - 3207
#
#                               Street Address          City State Postal Code  \
# 0                            Concourse A/FIS    Birmingham    AL       35212
# 1                   2850 Wall-Triana Highway    Huntsville    AL       35824
# 2                        150 N. Royal Street        Mobile    AL       36602
# 3                 Milepost 1221.8 Alaska Hwy         Alcan    AK       99780
# 4                            605 W. 4th Ave.     Anchorage    AK       99501
# 5                       Mile 40, Haines Hwy.  Dalton Cache    AK       99827
# 6                           6450 Airport Way     Fairbanks    AK       99709
# 7           1875 Shell Simmons Dr. Suite 116        Juneau    AK       99801
# 8                            648 Mission St.     Ketchikan    AK       99901
# 9                        c/o 605 W. 4th Ave.     Anchorage    AK       99501
# 10                       113 W. Front Street          Nome    AK       99762
# 11                            329 Harbor Dr.         Sitka    AK       99835
# 12               Milepost 6.8, Klondike Hwy.       Skagway    AK       99840
# 13        c/o 605 West 4th Avenue, Suite 230     Anchorage    AK       99501
# 14                       431 Zimovia Highway      Wrangell    AK       99929
# 15      First Street and Pan American Avenue       Douglas    AZ       85607
# 16                       Highway 85 & Border     Lukeville    AZ       85341
# 17                     3867 S. Towner Avenue          Naco    AZ       85620
# 18                        9 North Grand Ave.       Nogales    AZ       85621
# 19         3002 E. Old Tower Road, Suite 400       Phoenix    AZ       85034
# 20                      5803 S. Sossaman Rd.          Mesa    AZ       85212
# 21         Highway 95 & International Border      San Luis    AZ       85349
# 22      Highway 286 and International Border        Sasabe    AZ       85633
# 23                    15000 N. Airport Drive   Scottsdale,    AZ       85260
# 24                  7150 S. Tucson Boulevard        Tucson    AZ       85706
# 25                        1000 Temple Street   Little Rock    AR       72202
# 26                    #5 Hammerschmidt Drive        Rogers    AR       72756
# 27                          235 Andrade Road   Winterhaven    CA       92283
# 28                        1699 East Carr, Rd      Calexico    CA       92231
# 29                     200 East First Street      Calexico    CA       92231
# ..                                       ...           ...   ...         ...
# 304                No CBP personnel on site.   Front Royal    VA       22630
# 305                    No personnel on site.        Dublin    VA       24084
# 306                       101 E. Main Street       Norfolk    VA       23510
# 307                 22685 Holiday Park Drive      Sterling    VA       20598
# 308            5707 Huntsman Road, Suite 104      Richmond    VA       23250
# 309                     9901 Pacific Highway        Blaine    WA       98230
# 310                        1450 Terminal Way      Longview    WA       98632
# 311                             33643 Hwy 97      Oroville    WA       98844
# 312                  17801 Pacific Highway S       Seattle    WA  98158-1249
# 313                        103 Cherry Street         Sumas    WA       98295
# 314                 2202 Port of Tacoma Road        Tacoma    WA       98421
# 315                           Yeager Airport    Charleston    WV       25311
# 316            W6400 Challenger Dr. Ste. 100      Appleton    WI       54914
# 317                       2077 Airport Drive     Green Bay    WI       54313
# 318                    4915 S. Howell Avenue     Milwaukee    WI       53207
# 319                3239 North Green Bay Road        Racine    WI       53404
# 320            8500 Airport Pkwy, Suite 217.        Casper    WY       82604
# 321                 Rafael Hernandez Airport     Aguadilla    PR       00604
# 322                         U.S. Customhouse   Puerto Real    PR       00740
# 323                Ave. Baldorioty de Castro    Isla Verde    PR       00937
# 324                31 Gonzalez Clemente Ave.      Mayaguez    PR       00680
# 325                         63 Calle Bonaire         Ponce    PR       00716
# 326               City View Plaza-Suite 3000      Guaynabo    PR  00968-8000
# 327               Rota International Airport          Rota    MP       96951
# 328             Saipan International Airport        Saipan    MP       96950
# 329             Tinian International Airport        Tinian    MP       96950
# 330                      5500 Veterans Drive    St. Thomas    VI       00801
# 331                  Cruz Bay Creek Bulkhead      St. John    VI       00830
# 332                               RR #2-9922     Kingshill    VI       00850
# 333  A.B. Won Pat Guam International Airport      Tamuning    GU       96913
#
#              Field
# 0      New Orleans
# 1      New Orleans
# 2      New Orleans
# 3         Portland
# 4         Portland
# 5         Portland
# 6              NaN
# 7         Portland
# 8         Portland
# 9         Portland
# 10        Portland
# 11        Portland
# 12        Portland
# 13        Portland
# 14        Portland
# 15          Tucson
# 16          Tucson
# 17          Tucson
# 18          Tucson
# 19          Tucson
# 20          Tucson
# 21          Tucson
# 22          Tucson
# 23          Tucson
# 24          Tucson
# 25     New Orleans
# 26     New Orleans
# 27       San Diego
# 28       San Diego
# 29       San Diego
# ..             ...
# 304        Atlanta
# 305        Atlanta
# 306        Atlanta
# 307      Baltimore
# 308        Atlanta
# 309        Seattle
# 310       Portland
# 311        Seattle
# 312        Seattle
# 313            NaN
# 314        Seattle
# 315        Atlanta
# 316        Chicago
# 317        Chicago
# 318        Chicago
# 319        Chicago
# 320       Portland
# 321       San Juan
# 322       San Juan
# 323       San Juan
# 324       San Juan
# 325       San Juan
# 326       San Juan
# 327  San Francisco
# 328  San Francisco
# 329  San Francisco
# 330       San Juan
# 331       San Juan
# 332       San Juan
# 333  San Francisco
#
# [334 rows x 6 columns]

# %%
# Extract port code and set index
ports_df['Port Code'] = ports_df['Port Code'].str[-4:]
ports_df = ports_df.set_index('Port Code')
ports_df.head()
# Out:
#                        Street Address        City State Postal Code  \
# Port Code
# 1904                  Concourse A/FIS  Birmingham    AL       35212
# 1910         2850 Wall-Triana Highway  Huntsville    AL       35824
# 1901              150 N. Royal Street      Mobile    AL       36602
# 3104       Milepost 1221.8 Alaska Hwy       Alcan    AK       99780
# 3126                  605 W. 4th Ave.   Anchorage    AK       99501
#
#                  Field
# Port Code
# 1904       New Orleans
# 1910       New Orleans
# 1901       New Orleans
# 3104          Portland
# 3126          Portland

# %%
# Save dataframe as csv
ports_df.to_csv('Resources/US_CBP_Ports_Data.csv')

# %% [markdown]
# # Import CSVs

# %% [markdown]
# ### Paths

# %%
border_crossing_path = 'Resources/Border_Crossing_Entry_Data.csv'
acs_10_path = 'Resources/ACS_10_5YR_DP05_with_ann.csv'
acs_11_path = 'Resources/ACS_11_5YR_DP05_with_ann.csv'
acs_12_path = 'Resources/ACS_12_5YR_DP05_with_ann.csv'
acs_13_path = 'Resources/ACS_13_5YR_DP05_with_ann.csv'
acs_14_path = 'Resources/ACS_14_5YR_DP05_with_ann.csv'
acs_15_path = 'Resources/ACS_15_5YR_DP05_with_ann.csv'
acs_16_path = 'Resources/ACS_16_5YR_DP05_with_ann.csv'
acs_17_path = 'Resources/ACS_17_5YR_DP05_with_ann.csv'

# %% [markdown]
# ## Cleaning Border Crossing Dataframe

# %%
# Create Dataframe from Border Crossing data.
border_crossing_df = pd.read_csv(border_crossing_path)
border_crossing_df.head()
# Out:
#        Port Name       State  Port Code            Border  \
# 0  Calexico East  California       2507  US-Mexico Border
# 1      Van Buren       Maine        108  US-Canada Border
# 2      Otay Mesa  California       2506  US-Mexico Border
# 3        Nogales     Arizona       2604  US-Mexico Border
# 4    Trout River    New York        715  US-Canada Border
#
#                      Date                      Measure  Value  \
# 0  03/01/2019 12:00:00 AM                       Trucks  34447
# 1  03/01/2019 12:00:00 AM         Rail Containers Full    428
# 2  03/01/2019 12:00:00 AM                       Trucks  81217
# 3  03/01/2019 12:00:00 AM                       Trains     62
# 4  03/01/2019 12:00:00 AM  Personal Vehicle Passengers  16377
#
#                                 Location
# 0   POINT (-115.48433000000001 32.67524)
# 1             POINT (-67.94271 47.16207)
# 2            POINT (-117.05333 32.57333)
# 3  POINT (-110.93361 31.340279999999996)
# 4   POINT (-73.44253 44.990010000000005)

# %%
# Check types
border_crossing_df.dtypes
# Out:
# Port Name    object
# State        object
# Port Code     int64
# Border       object
# Date         object
# Measure      object
# Value         int64
# Location     object
# dtype: object

# %%
# Remove the time from Date. It is unnecessary.
border_crossing_df.Date = pd.to_datetime(border_crossing_df.Date).dt.normalize()
border_crossing_df.head()
# Out:
#        Port Name       State  Port Code            Border       Date  \
# 0  Calexico East  California       2507  US-Mexico Border 2019-03-01
# 1      Van Buren       Maine        108  US-Canada Border 2019-03-01
# 2      Otay Mesa  California       2506  US-Mexico Border 2019-03-01
# 3        Nogales     Arizona       2604  US-Mexico Border 2019-03-01
# 4    Trout River    New York        715  US-Canada Border 2019-03-01
#
#                        Measure  Value                               Location
# 0                       Trucks  34447   POINT (-115.48433000000001 32.67524)
# 1         Rail Containers Full    428             POINT (-67.94271 47.16207)
# 2                       Trucks  81217            POINT (-117.05333 32.57333)
# 3                       Trains     62  POINT (-110.93361 31.340279999999996)
# 4  Personal Vehicle Passengers  16377   POINT (-73.44253 44.990010000000005)

# %%
# Clean Location column and split into two columns: latitude, longitude

# Remove 'POINT (' and ')'
border_crossing_df.Location = border_crossing_df.Location.map(lambda x: x.lstrip('POINT (').rstrip(')'))

# Split lat and lng
lat = []
lng = []
for row in border_crossing_df.Location:
    try:
        lat.append(row.split(' ')[0])
        lng.append(row.split(' ')[1])
    except:
        lat.append(np.NaN)
        lng.append(np.NaN)
        
# Create new column for lat and lng, then drop Location column.
border_crossing_df['Latitude'] = lat
border_crossing_df['Longitude'] = lng
border_crossing_df = border_crossing_df.drop(columns='Location')

border_crossing_df.head()
# Out:
#        Port Name       State  Port Code            Border       Date  \
# 0  Calexico East  California       2507  US-Mexico Border 2019-03-01
# 1      Van Buren       Maine        108  US-Canada Border 2019-03-01
# 2      Otay Mesa  California       2506  US-Mexico Border 2019-03-01
# 3        Nogales     Arizona       2604  US-Mexico Border 2019-03-01
# 4    Trout River    New York        715  US-Canada Border 2019-03-01
#
#                        Measure  Value             Latitude           Longitude
# 0                       Trucks  34447  -115.48433000000001            32.67524
# 1         Rail Containers Full    428            -67.94271            47.16207
# 2                       Trucks  81217           -117.05333            32.57333
# 3                       Trains     62           -110.93361  31.340279999999996
# 4  Personal Vehicle Passengers  16377            -73.44253  44.990010000000005

# %%
# Save dataframe to csv
border_crossing_df.to_csv('Resources/Border_Crossing_Entry_Data_Clean.csv')

# %% [markdown]
# ## Cleaning Demographics Data

# %%
column_imports = [2,111] + [i for i in range(127,281) if i % 2 != 0]
column_imports_2017 = [2,131] + [i for i in range(147,301) if i % 2 != 0]

# %%
# 2010
acs_10_df = pd.read_csv(acs_10_path, usecols=column_imports)
acs_10_df = acs_10_df.drop([0],axis=0)
acs_10_df = acs_10_df.rename(columns={'GEO.display-label':'State'})
acs_10_df.insert(1, 'Year', '2010')
acs_10_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2010   4712651   3293917      69.9   1232325      26.1
# 2      Alaska  2010    691189    464150      67.2     22655       3.3
# 3     Arizona  2010   6246816   4883606      78.2    240655       3.9
# 4    Arkansas  2010   2872684   2253875      78.5    445197      15.5
# 5  California  2010  36637290  22392713      61.1   2246311       6.1
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     25814       0.5      9702  ...   4712651    162371       3.4    111664
# 2     98120      14.2       788  ...    691189     38393       5.6     22059
# 3    278336       4.5      4042  ...   6246816   1814674      29.0   1631468
# 4     19192       0.7      8826  ...   2872684    168427       5.9    128480
# 5    283628       0.8     23855  ...  36637290  13456157      36.7  11231410
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.4     11011       0.2      4017       0.1     35679
# 2       3.2      4380       0.6       780       0.1     11174
# 3      26.1     30532       0.5      8944       0.1    143730
# 4       4.5      4740       0.2       754       0.0     34453
# 5      30.7    172746       0.5     82788       0.2   1969213
#
# [5 rows x 80 columns]

# %%
# 2011
acs_11_df = pd.read_csv(acs_11_path, usecols=column_imports)
acs_11_df = acs_11_df.drop([0],axis=0)
acs_11_df = acs_11_df.rename(columns={'GEO.display-label':'State'})
acs_11_df.insert(1, 'Year', '2011')
acs_11_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2011   4747424   3307557      69.7   1244112      26.2
# 2      Alaska  2011    700703    472504      67.4     23426       3.3
# 3     Arizona  2011   6337373   4987541      78.7    252127       4.0
# 4    Arkansas  2011   2895928   2271277      78.4    449283      15.5
# 5  California  2011  36969200  22860341      61.8   2252129       6.1
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     26399       0.6      9792  ...   4747424    173990       3.7    121153
# 2     97628      13.9       794  ...    700703     39212       5.6     22373
# 3    280986       4.4      3616  ...   6337373   1864375      29.4   1683280
# 4     17239       0.6      7242  ...   2895928    177869       6.1    137142
# 5    287712       0.8     23618  ...  36969200  13752743      37.2  11493037
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.6     11770       0.2      3475       0.1     37592
# 2       3.2      4973       0.7       875       0.1     10991
# 3      26.6     30965       0.5      9112       0.1    141018
# 4       4.7      5446       0.2       921       0.0     34360
# 5      31.1    183059       0.5     83192       0.2   1993455
#
# [5 rows x 80 columns]

# %%
# 2012
acs_12_df = pd.read_csv(acs_12_path, usecols=column_imports)
acs_12_df = acs_12_df.drop([0],axis=0)
acs_12_df = acs_12_df.rename(columns={'GEO.display-label':'State'})
acs_12_df.insert(1, 'Year', '2012')
acs_12_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2012   4777326   3321318      69.5   1256097      26.3
# 2      Alaska  2012    711139    477985      67.2     24219       3.4
# 3     Arizona  2012   6410979   5085954      79.3    262284       4.1
# 4    Arkansas  2012   2916372   2285577      78.4    453062      15.5
# 5  California  2012  37325068  23252553      62.3   2254160       6.0
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     26166       0.5      9604  ...   4777326    182268       3.8    127306
# 2     98976      13.9       980  ...    711139     40371       5.7     22618
# 3    283805       4.4      3151  ...   6410979   1902946      29.7   1724678
# 4     17390       0.6      7306  ...   2916372    185239       6.4    144586
# 5    291505       0.8     23701  ...  37325068  14024109      37.6  11727067
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.7     12386       0.3      3657       0.1     38919
# 2       3.2      4920       0.7      1087       0.2     11746
# 3      26.9     32463       0.5      9485       0.1    136320
# 4       5.0      5241       0.2       860       0.0     34552
# 5      31.4    189764       0.5     85124       0.2   2022154
#
# [5 rows x 80 columns]

# %%
# 2013
acs_13_df = pd.read_csv(acs_13_path, usecols=column_imports)
acs_13_df = acs_13_df.drop([0],axis=0)
acs_13_df = acs_13_df.rename(columns={'GEO.display-label':'State'})
acs_13_df.insert(1, 'Year', '2013')
acs_13_df.columns = acs_10_df.columns
acs_13_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2013   4799277   3326188      69.3   1262152      26.3
# 2      Alaska  2013    720316    481638      66.9     25033       3.5
# 3     Arizona  2013   6479703   5131739      79.2    270027       4.2
# 4    Arkansas  2013   2933369   2295446      78.3    454903      15.5
# 5  California  2013  37659181  23467167      62.3   2255372       6.0
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     25278       0.5      9180  ...   4799277    188294       3.9    129237
# 2    101273      14.1       723  ...    720316     42832       5.9     23318
# 3    286953       4.4      3519  ...   6479703   1935948      29.9   1749835
# 4     17945       0.6      7472  ...   2933369    192264       6.6    149054
# 5    286397       0.8     23070  ...  37659181  14270345      37.9  11917361
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.7     14190       0.3      3907       0.1     40960
# 2       3.2      5733       0.8       866       0.1     12915
# 3      27.0     35765       0.6     10733       0.2    139615
# 4       5.1      5521       0.2       886       0.0     36803
# 5      31.6    197899       0.5     89188       0.2   2065897
#
# [5 rows x 80 columns]

# %%
# 2014
acs_14_df = pd.read_csv(acs_14_path, usecols=column_imports)
acs_14_df = acs_14_df.drop([0],axis=0)
acs_14_df = acs_14_df.rename(columns={'GEO.display-label':'State'})
acs_14_df.insert(1, 'Year', '2014')
acs_14_df.columns = acs_10_df.columns
acs_14_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2014   4817678   3327891      69.1   1269808      26.4
# 2      Alaska  2014    728300    484195      66.5     25148       3.5
# 3     Arizona  2014   6561516   5174082      78.9    274380       4.2
# 4    Arkansas  2014   2947036   2306073      78.3    458136      15.5
# 5  California  2014  38066920  23650913      62.1   2262323       5.9
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     25181       0.5      9651  ...   4817678    191838       4.0    128902
# 2    102743      14.1       712  ...    728300     45247       6.2     25922
# 3    290780       4.4      3399  ...   6561516   1977026      30.1   1784013
# 4     18337       0.6      7367  ...   2947036    198109       6.7    151482
# 5    287360       0.8     22525  ...  38066920  14534449      38.2  12108744
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.7     14814       0.3      4667       0.1     43455
# 2       3.6      6312       0.9       855       0.1     12158
# 3      27.2     37301       0.6     12778       0.2    142934
# 4       5.1      5121       0.2      1230       0.0     40276
# 5      31.8    207878       0.5     92022       0.2   2125805
#
# [5 rows x 80 columns]

# %%
# 2015
acs_15_df = pd.read_csv(acs_15_path, usecols=column_imports)
acs_15_df = acs_15_df.drop([0],axis=0)
acs_15_df = acs_15_df.rename(columns={'GEO.display-label':'State'})
acs_15_df.insert(1, 'Year', '2015')
acs_15_df.columns = acs_10_df.columns
acs_15_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2015   4830620   3325464      68.8   1276544      26.4
# 2      Alaska  2015    733375    484250      66.0     25022       3.4
# 3     Arizona  2015   6641928   5210335      78.4    281576       4.2
# 4    Arkansas  2015   2958208   2307849      78.0    459748      15.5
# 5  California  2015  38421464  23747013      61.8   2265387       5.9
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     23850       0.5      8870  ...   4830620    193492       4.0    128381
# 2    101313      13.8       585  ...    733375     47808       6.5     25774
# 3    294721       4.4      2817  ...   6641928   2014711      30.3   1813659
# 4     18409       0.6      7274  ...   2958208    203226       6.9    152982
# 5    287028       0.7     21962  ...  38421464  14750686      38.4  12274907
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.7     14524       0.3      5155       0.1     45432
# 2       3.5      6772       0.9       899       0.1     14363
# 3      27.3     38540       0.6     12888       0.2    149624
# 4       5.2      5594       0.2      1507       0.1     43143
# 5      31.9    209771       0.5     91274       0.2   2174734
#
# [5 rows x 80 columns]

# %%
# 2016
acs_16_df = pd.read_csv(acs_16_path, usecols=column_imports)
acs_16_df = acs_16_df.drop([0],axis=0)
acs_16_df = acs_16_df.rename(columns={'GEO.display-label':'State'})
acs_16_df.insert(1, 'Year', '2016')
acs_16_df.columns = acs_10_df.columns
acs_16_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2016   4841164   3325037      68.7   1282053      26.5
# 2      Alaska  2016    736855    483518      65.6     24443       3.3
# 3     Arizona  2016   6728577   5235158      77.8    287110       4.3
# 4    Arkansas  2016   2968472   2307136      77.7    460638      15.5
# 5  California  2016  38654206  23680584      61.3   2261835       5.9
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     23919       0.5      8651  ...   4841164    193503       4.0    124935
# 2    103574      14.1       745  ...    736855     49031       6.7     26187
# 3    296732       4.4      3049  ...   6728577   2054849      30.5   1845058
# 4     18697       0.6      7698  ...   2968472    207049       7.0    154215
# 5    285512       0.7     19707  ...  38654206  14903982      38.6  12400437
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.6     16391       0.3      5423       0.1     46754
# 2       3.6      7061       1.0       822       0.1     14961
# 3      27.4     41598       0.6     13545       0.2    154648
# 4       5.2      5973       0.2      1798       0.1     45063
# 5      32.1    210940       0.5     93974       0.2   2198631
#
# [5 rows x 80 columns]

# %%
#2017
acs_17_df = pd.read_csv(acs_17_path, usecols=column_imports_2017)
acs_17_df = acs_17_df.drop([0],axis=0)
acs_17_df = acs_17_df.rename(columns={'GEO.display-label':'State'})
acs_17_df.insert(1, 'Year', '2017')
acs_17_df.columns = acs_10_df.columns
acs_17_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 1     Alabama  2017   4850771   3317702      68.4   1287167      26.5
# 2      Alaska  2017    738565    481971      65.3     23702       3.2
# 3     Arizona  2017   6809946   5277661      77.5    292831       4.3
# 4    Arkansas  2017   2977944   2302141      77.3    459969      15.4
# 5  California  2017  38982847  23607242      60.6   2263222       5.8
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 1     25098       0.5      9673  ...   4850771    198375       4.1    123596
# 2    104995      14.2       714  ...    738565     50162       6.8     27254
# 3    300182       4.4      3005  ...   6809946   2103523      30.9   1884425
# 4     19476       0.7      8000  ...   2977944    213246       7.2    158362
# 5    292018       0.7     19015  ...  38982847  15105860      38.8  12555044
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 1       2.5     17833       0.4      5324       0.1     51622
# 2       3.7      7332       1.0       813       0.1     14763
# 3      27.7     43693       0.6     14702       0.2    160703
# 4       5.3      6235       0.2      2074       0.1     46575
# 5      32.2    215163       0.6     96754       0.2   2238899
#
# [5 rows x 80 columns]

# %%
# Combine all ACS together
acs_combine_df = acs_10_df.copy()
acs_combine_df = acs_combine_df.append(acs_11_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_12_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_13_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_14_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_15_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_16_df, sort=False)
acs_combine_df = acs_combine_df.append(acs_17_df, sort=False)
acs_combine_df = acs_combine_df.reset_index(drop=True)
acs_combine_df.head()
# Out:
#         State  Year HC01_VC38 HC01_VC43 HC03_VC43 HC01_VC44 HC03_VC44  \
# 0     Alabama  2010   4712651   3293917      69.9   1232325      26.1
# 1      Alaska  2010    691189    464150      67.2     22655       3.3
# 2     Arizona  2010   6246816   4883606      78.2    240655       3.9
# 3    Arkansas  2010   2872684   2253875      78.5    445197      15.5
# 4  California  2010  36637290  22392713      61.1   2246311       6.1
#
#   HC01_VC45 HC03_VC45 HC01_VC46  ... HC03_VC81 HC01_VC82 HC03_VC82 HC01_VC83  \
# 0     25814       0.5      9702  ...   4712651    162371       3.4    111664
# 1     98120      14.2       788  ...    691189     38393       5.6     22059
# 2    278336       4.5      4042  ...   6246816   1814674      29.0   1631468
# 3     19192       0.7      8826  ...   2872684    168427       5.9    128480
# 4    283628       0.8     23855  ...  36637290  13456157      36.7  11231410
#
#   HC03_VC83 HC01_VC84 HC03_VC84 HC01_VC85 HC03_VC85 HC01_VC86
# 0       2.4     11011       0.2      4017       0.1     35679
# 1       3.2      4380       0.6       780       0.1     11174
# 2      26.1     30532       0.5      8944       0.1    143730
# 3       4.5      4740       0.2       754       0.0     34453
# 4      30.7    172746       0.5     82788       0.2   1969213
#
# [5 rows x 80 columns]

# %%
# Save ACS Combine to csv
acs_combine_df.to_csv('Resources/ACS_Combine.csv')
